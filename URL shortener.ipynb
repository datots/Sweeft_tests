# %%
import pyshorteners
simple_url = input("Enter the URL to make it little: ")
 
type_tiny = pyshorteners.Shortener()
short_url = type_tiny.tinyurl.short(simple_url)
 
print("The little URL is: " + short_url)
# Out:
# Enter the URL to make it little: https://www.youtube.com/watch?v=lYMM7egm_9M&t=103s
# The little URL is: https://tinyurl.com/22lofut5
# Oversized

# %%
import pyshorteners
simple_url = input("Enter the URL to make it little: ")
name = input('custom name: ') 


type_tiny = pyshorteners.Shortener()
short_url = type_tiny.tinyurl.short(simple_url)
 
print("The little URL is: " + short_url)
# Out:
# Enter the URL to make it little: shorten url with custom name
#  custom name: Youtube
# The little URL is: 'name' https://tinyurl.com/23smjos2

# %%
import validators

URL=validators.url('https://tinyurl.com/22lofut5')
if URL==True:
    print("Url is valid")
else:
    print("Invalid url")
# Out:
# Url is valid

# %%
if len(short_url) > 250:
    print('Size is good')
else:
    print('Oversized')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 if len(short_url) > 250:
#       2     print('Size is good')
#       3 else:
#
# NameError: name 'short_url' is not defined
